# %% [markdown]
# <a href="https://colab.research.google.com/github/SorenBC/math-data-science-couse-project-three-Soren-Callo/blob/main/project3SorenCallo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Math 5750/6880: Mathematics of Data Science \
# Project 3

# %% [markdown]
# # 1. Fashion-MNIST image classification using sklearn

# %%
from tensorflow.keras.datasets import fashion_mnist
from sklearn.preprocessing import StandardScaler

# Load Fashion-MNIST
# Classes (0-9): T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train = X_train.reshape(len(X_train), -1)
X_test  = X_test.reshape(len(X_test), -1)

# Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# your code here
mlp = MLPClassifier(hidden_layer_sizes=(1000, 100), max_iter=1000,random_state=17)
mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8858
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.81      1000
#            1       0.99      0.97      0.98      1000
#            2       0.76      0.86      0.81      1000
#            3       0.91      0.89      0.90      1000
#            4       0.83      0.80      0.82      1000
#            5       0.95      0.98      0.97      1000
#            6       0.69      0.70      0.69      1000
#            7       0.96      0.95      0.96      1000
#            8       0.97      0.97      0.97      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
print(confusion_matrix(y_test, y_pred))

from matplotlib import pyplot as plt

plt.imshow(confusion_matrix(y_test, y_pred), cmap='Blues')
plt.show()

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# [[782   0  26  19   4   0 163   0   6   0]
#  [  8 974   1   9   4   0   3   0   1   0]
#  [ 20   0 859  12  52   1  53   0   3   0]
#  [ 15   5  14 892  42   0  28   0   4   0]
#  [  0   0 112  24 802   0  60   0   2   0]
#  [  0   0   0   0   0 984   0  10   1   5]
#  [105   3 108  20  58   0 696   0  10   0]
#  [  0   0   1   0   0  22   0 954   0  23]
#  [  7   0   6   6   6   6   2   1 966   0]
#  [  0   0   0   0   0  20   1  26   4 949]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.81      1000
#            1       0.99      0.97      0.98      1000
#            2       0.76      0.86      0.81      1000
#            3       0.91      0.89      0.90      1000
#            4       0.83      0.80      0.82      1000
#            5       0.95      0.98      0.97      1000
#            6       0.69      0.70      0.69      1000
#            7       0.96      0.95      0.96      1000
# ...

# %%
# Experiments

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# your code here
mlp = MLPClassifier(hidden_layer_sizes=(1000, 100), max_iter=1000,random_state=17, solver = 'lbfgs', alpha=0.1, early_stopping=True)
mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

print(confusion_matrix(y_test, y_pred))

from matplotlib import pyplot as plt

plt.imshow(confusion_matrix(y_test, y_pred), cmap='Blues')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3-1821522270.py in <cell line: 0>()
#       6 # your code here
#       7 mlp = MLPClassifier(hidden_layer_sizes=(1000, 100), max_iter=1000,random_state=17, solver = 'lbfgs', alpha=0.1, early_stopping=True)
# ----> 8 mlp.fit(X_train, y_train)
#       9 y_pred = mlp.predict(X_test)
#      10 print("Accuracy:", accuracy_score(y_test, y_pred))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in fit(self, X, y)
#     752             Returns a trained MLP model.
#     753         """
# ...

# %%
y_pred = mlp.predict(X_test)

print(confusion_matrix(y_test, y_pred))

from matplotlib import pyplot as plt

plt.imshow(confusion_matrix(y_test, y_pred), cmap='Blues')
plt.show()

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# [[832   3  13  21   8   0 115   0   8   0]
#  [  2 981   3   8   3   0   3   0   0   0]
#  [ 24   0 832  12  71   1  57   0   3   0]
#  [ 27  10  14 873  38   0  34   0   3   1]
#  [  0   1  88  23 830   0  56   0   2   0]
#  [  0   0   0   1   0 957   0  19   2  21]
#  [117   0  80  26  69   0 700   0   8   0]
#  [  0   0   0   0   0  18   0 952   0  30]
#  [  4   0   3   5   4   3   7   5 969   0]
#  [  0   0   0   0   0   9   1  29   0 961]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      1000
#            1       0.99      0.98      0.98      1000
#            2       0.81      0.83      0.82      1000
#            3       0.90      0.87      0.89      1000
#            4       0.81      0.83      0.82      1000
#            5       0.97      0.96      0.96      1000
#            6       0.72      0.70      0.71      1000
#            7       0.95      0.95      0.95      1000
# ...

# %% [markdown]
# # 3. Fashion-MNIST image classification  using pytorch

# %%
import numpy as np
from tensorflow.keras.datasets import fashion_mnist
import torch
from torch.utils.data import TensorDataset, DataLoader

# Load Fashion-MNIST
# Classes (0-9): T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# scale to [0,1], add channel dimension -> (N, 1, 28, 28)
X_train = (X_train.astype("float32") / 255.0)[:, None, :, :]
X_test  = (X_test.astype("float32")  / 255.0)[:,  None, :, :]

y_train = y_train.astype(np.int64)
y_test  = y_test.astype(np.int64)

# train/val split: last 10k of train as validation
X_tr, X_val = X_train[:50000], X_train[50000:]
y_tr, y_val = y_train[:50000], y_train[50000:]

# wrap in PyTorch TensorDatasets and DataLoaders
train_ds = TensorDataset(torch.from_numpy(X_tr),  torch.from_numpy(y_tr))
val_ds   = TensorDataset(torch.from_numpy(X_val), torch.from_numpy(y_val))
test_ds  = TensorDataset(torch.from_numpy(X_test), torch.from_numpy(y_test))

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=256, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=256, shuffle=False)

# %%
import torch.nn as nn
import torch.optim as optim

# In colab, you should ``change runtime type'' to GPU.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# your code here
# define model
class NeuralNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(784, 1000),
            nn.ReLU(),
            nn.Linear(1000, 500),
            nn.ReLU(),
            nn.Linear(500, 25),
            nn.ReLU(),
            nn.Linear(25, 10),
        )
    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model1 = NeuralNet().to(device)
print(model1)
# Out:
# Using device: cuda
# NeuralNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=1000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1000, out_features=500, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=500, out_features=25, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=25, out_features=10, bias=True)
#   )
# )

# %%
print(model1(torch.from_numpy(X_test).to(device))[:10])
print(y_test[:10])
# Out:
# tensor([[-0.0298,  0.1421, -0.0873,  0.1274,  0.1779,  0.0012,  0.0645,  0.0528,
#          -0.1265,  0.0431],
#         [-0.0385,  0.1076, -0.1154,  0.1220,  0.1653, -0.0099,  0.0472,  0.0674,
#          -0.1362,  0.0483],
#         [-0.0168,  0.1141, -0.0793,  0.1290,  0.1709, -0.0128,  0.0498,  0.0791,
#          -0.1215,  0.0386],
#         [-0.0097,  0.1208, -0.0705,  0.1355,  0.1690, -0.0141,  0.0542,  0.0759,
#          -0.1206,  0.0387],
#         [-0.0360,  0.1281, -0.0877,  0.1301,  0.1767, -0.0074,  0.0523,  0.0776,
#          -0.1262,  0.0359],
#         [-0.0213,  0.1137, -0.0841,  0.1279,  0.1749, -0.0095,  0.0456,  0.0743,
#          -0.1302,  0.0415],
#         [-0.0322,  0.1366, -0.0769,  0.1273,  0.1841, -0.0010,  0.0627,  0.0652,
#          -0.1315,  0.0410],
#         [-0.0235,  0.1332, -0.0783,  0.1391,  0.1741, -0.0084,  0.0543,  0.0697,
#          -0.1295,  0.0350],
#         [-0.0274,  0.1368, -0.0666,  0.1372,  0.1852, -0.0107,  0.0612,  0.0776,
# ...

# %%
# loss function
loss_fn = nn.CrossEntropyLoss()
# optimizer
optimizer = torch.optim.Adam(model1.parameters(), lr=0.01)

# %%
num_epochs = 50
train_loss = []
val_loss = []

for epoch in range(num_epochs):
  model1.train()
  running_loss = 0.0
  for images, classes in train_loader:
    images, classes = images.to(device), classes.to(device)
    optimizer.zero_grad()
    outputs = model1(images)
    l1_norm = sum(p.abs().sum() for p in model1.parameters())
    loss = loss_fn(outputs, classes) + 0.001 * l1_norm
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
  train_loss.append(running_loss / len(train_loader.dataset))

  model1.eval()
  running_loss = 0.0
  with torch.no_grad():
    for images, classes in val_loader:
      images, classes = images.to(device), classes.to(device)
      outputs = model1(images)
      loss = loss_fn(outputs, classes)
      running_loss += loss.item()
  val_loss.append(running_loss / len(val_loader.dataset))

  if epoch % 10 == 0:
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss[-1]:.4f}, Val Loss: {val_loss[-1]:.4f}")
# Out:
# Epoch 1/50, Train Loss: 0.0306, Val Loss: 0.0045
# Epoch 11/50, Train Loss: 0.0174, Val Loss: 0.0024
# Epoch 21/50, Train Loss: 0.0170, Val Loss: 0.0030
# Epoch 31/50, Train Loss: 0.0172, Val Loss: 0.0021
# Epoch 41/50, Train Loss: 0.0176, Val Loss: 0.0021

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
outputs = model1(torch.from_numpy(X_test).to(device))
_, predicted = torch.max(outputs, 1)
print(classification_report(y_test, predicted.cpu().numpy()))

print(accuracy_score(y_test, predicted.cpu().numpy()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.76      1000
#            1       0.98      0.93      0.95      1000
#            2       0.63      0.79      0.70      1000
#            3       0.73      0.88      0.80      1000
#            4       0.78      0.56      0.65      1000
#            5       0.94      0.88      0.91      1000
#            6       0.57      0.39      0.46      1000
#            7       0.84      0.95      0.89      1000
#            8       0.92      0.91      0.91      1000
#            9       0.94      0.88      0.91      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.80      0.79     10000
# weighted avg       0.80      0.80      0.79     10000
#
# 0.7994

# %%
print(confusion_matrix(y_test, predicted.cpu().numpy()))

from matplotlib import pyplot as plt

plt.imshow(confusion_matrix(y_test, predicted.cpu().numpy()), cmap='Blues')
plt.show()
# Out:
# [[829   3  15  96   0   3  44   0  10   0]
#  [  1 927  18  50   2   0   1   0   1   0]
#  [ 27   1 787  19  82   0  77   0   7   0]
#  [ 61   6  11 884   8   0  25   0   5   0]
#  [  1   0 249  77 556   0 106   0  11   0]
#  [  0   0   0   2   0 883   0  77   4  34]
#  [274   4 170  64  66   0 392   0  30   0]
#  [  0   0   0   0   0  22   0 952   0  26]
#  [  3   1   4  20   3  11  46   6 905   1]
#  [  0   0   0   0   0  16   0  96   9 879]]

# %% [markdown]
# Pretrained Model

# %%
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim

pretrained_model = models.resnet50(pretrained=True)

class ModifiedResNet(nn.Module):
    def __init__(self):
        super(ModifiedResNet, self).__init__()
        self.resnet = torch.hub.load('pytorch/vision', 'resnet50', pretrained=True)
        num_classes = 10  # MNIST has 10 classes
        self.resnet.fc = nn.Linear(pretrained_model.fc.in_features, num_classes)  # Change the final fully connected layer for 10 classes

    def forward(self, x):
        return self.resnet(x)

model2 = ModifiedResNet()
for param in model2.parameters():
    param.requires_grad = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model2.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 134MB/s]
# Downloading: "https://github.com/pytorch/vision/zipball/main" to /root/.cache/torch/hub/main.zip
# ModifiedResNet(
#   (resnet): ResNet(
# ...

# %%
# loss function
loss_fn = nn.CrossEntropyLoss()
# optimizer
optimizer = torch.optim.SGD(model2.parameters(), lr=0.001)

# %%
import numpy as np
from tensorflow.keras.datasets import fashion_mnist
import torch
from torch.utils.data import TensorDataset, DataLoader
from torchvision import transforms

# Define transforms
transform_train = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

transform_test = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

# Load Fashion-MNIST
# Classes (0-9): T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

from PIL import Image

X_train_transformed = torch.stack([transform_train(Image.fromarray(x)) for x in X_train])
X_test_transformed = torch.stack([transform_test(Image.fromarray(x)) for x in X_test])

y_train = y_train.astype(np.int64)
y_test  = y_test.astype(np.int64)

# train/val split: last 10k of train as validation
X_tr, X_val = X_train_transformed[:50000], X_train_transformed[50000:]
y_tr, y_val = y_train[:50000], y_train[50000:]

# wrap in PyTorch TensorDatasets and DataLoaders
train_ds = TensorDataset(X_tr,  torch.from_numpy(y_tr))
val_ds   = TensorDataset(X_val, torch.from_numpy(y_val))
test_ds  = TensorDataset(X_test_transformed,  torch.from_numpy(y_test))

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=256, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=256, shuffle=False)

# %%
num_epochs = 50
train_loss_pretrained = []
val_loss_pretrained = []

for param in model2.resnet.layer4.parameters():
    param.requires_grad = True

for epoch in range(num_epochs):
  model2.train()
  running_loss = 0.0
  for images, classes in train_loader:
    images, classes = images.to(device), classes.to(device)
    optimizer.zero_grad()
    outputs = model2(images)
    loss = loss_fn(outputs, classes)
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
  train_loss_pretrained.append(running_loss / len(train_loader.dataset))

  model2.eval()
  running_loss = 0.0
  with torch.no_grad():
    for images, classes in val_loader:
      images, classes = images.to(device), classes.to(device)
      outputs = model2(images)
      loss = loss_fn(outputs, classes)
      running_loss += loss.item()
  val_loss_pretrained.append(running_loss / len(val_loader.dataset))

  print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss_pretrained[-1]:.4f}, Val Loss: {val_loss_pretrained[-1]:.4f}")
# Out:
# Epoch 1/50, Train Loss: 0.0148, Val Loss: 0.0058
# Epoch 2/50, Train Loss: 0.0093, Val Loss: 0.0040
# Epoch 3/50, Train Loss: 0.0069, Val Loss: 0.0032
# Epoch 4/50, Train Loss: 0.0058, Val Loss: 0.0029
# Epoch 5/50, Train Loss: 0.0052, Val Loss: 0.0026
# Epoch 6/50, Train Loss: 0.0048, Val Loss: 0.0025
# Epoch 7/50, Train Loss: 0.0045, Val Loss: 0.0024
# Epoch 8/50, Train Loss: 0.0043, Val Loss: 0.0023
# Epoch 9/50, Train Loss: 0.0041, Val Loss: 0.0023
# Epoch 10/50, Train Loss: 0.0039, Val Loss: 0.0022
# Epoch 11/50, Train Loss: 0.0038, Val Loss: 0.0022
# Epoch 12/50, Train Loss: 0.0036, Val Loss: 0.0021
# Epoch 13/50, Train Loss: 0.0035, Val Loss: 0.0021
# Epoch 14/50, Train Loss: 0.0034, Val Loss: 0.0021
# Epoch 15/50, Train Loss: 0.0033, Val Loss: 0.0020
# Epoch 16/50, Train Loss: 0.0032, Val Loss: 0.0020
# Epoch 17/50, Train Loss: 0.0031, Val Loss: 0.0020
# Epoch 18/50, Train Loss: 0.0030, Val Loss: 0.0020
# Epoch 19/50, Train Loss: 0.0029, Val Loss: 0.0020
# ...

# %%
outputs = model2(X_test_transformed.to(device))
_, predicted = torch.max(outputs, 1)
print(classification_report(y_test, predicted.cpu().numpy()))
print(accuracy_score(y_test, predicted.cpu().numpy()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79      1000
#            1       0.97      0.96      0.96      1000
#            2       0.69      0.78      0.74      1000
#            3       0.85      0.82      0.83      1000
#            4       0.75      0.70      0.72      1000
#            5       0.96      0.93      0.94      1000
#            6       0.60      0.55      0.57      1000
#            7       0.89      0.95      0.92      1000
#            8       0.96      0.96      0.96      1000
#            9       0.96      0.94      0.95      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000
#
# 0.8394

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.plot(train_loss_pretrained, label='Train Loss Pretrained')
plt.plot(val_loss_pretrained, label='Validation Loss Pretrained')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
confusion_matrix(y_test, predicted.cpu().numpy())

plt.imshow(confusion_matrix(y_test, predicted.cpu().numpy()), cmap='Blues')
plt.show()

# %% [markdown]
# Convolution

# %%
import numpy as np
from tensorflow.keras.datasets import fashion_mnist
import torch
from torch.utils.data import TensorDataset, DataLoader

# Load Fashion-MNIST
# Classes (0-9): T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# scale to [0,1], add channel dimension -> (N, 1, 28, 28)
X_train = (X_train.astype("float32") / 255.0)[:, None, :, :]
X_test  = (X_test.astype("float32")  / 255.0)[:,  None, :, :]

y_train = y_train.astype(np.int64)
y_test  = y_test.astype(np.int64)

# train/val split: last 10k of train as validation
X_tr, X_val = X_train[:50000], X_train[50000:]
y_tr, y_val = y_train[:50000], y_train[50000:]

# wrap in PyTorch TensorDatasets and DataLoaders
train_ds = TensorDataset(torch.from_numpy(X_tr),  torch.from_numpy(y_tr))
val_ds   = TensorDataset(torch.from_numpy(X_val), torch.from_numpy(y_val))
test_ds  = TensorDataset(torch.from_numpy(X_test), torch.from_numpy(y_test))

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=256, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=256, shuffle=False)

# %%
import torch.nn as nn
import torch.optim as optim

# In colab, you should ``change runtime type'' to GPU.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

class ConvolutionNet(nn.Module):
    def __init__(self):
        super(ConvolutionNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.max_pool2d = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = nn.functional.relu(x)
        x = self.conv2(x)
        x = nn.functional.relu(x)
        x = nn.functional.max_pool2d(x, 2)
        x = self.fc1(x.view(-1, 9216))
        x = nn.functional.relu(x)
        x = self.fc2(x)
        return x

model3 = ConvolutionNet().to(device)
# Out:
# Using device: cuda

# %%
model3(torch.from_numpy(X_test).to(device)[:10])
# Out:
# tensor([[-0.0300,  0.0706, -0.0805, -0.0926, -0.0970,  0.0799,  0.0799,  0.0713,
#           0.0688, -0.0018],
#         [-0.0590,  0.1000, -0.0773, -0.1271, -0.1012,  0.1370,  0.0495,  0.0724,
#           0.0495,  0.0038],
#         [-0.0591,  0.1045, -0.0759, -0.0890, -0.1033,  0.1050,  0.0274,  0.0759,
#           0.0646,  0.0100],
#         [-0.0498,  0.0850, -0.0758, -0.0778, -0.0976,  0.0955,  0.0568,  0.0680,
#           0.0471,  0.0017],
#         [-0.0503,  0.0878, -0.0777, -0.1068, -0.1063,  0.0936,  0.0645,  0.0765,
#           0.0619, -0.0100],
#         [-0.0628,  0.0934, -0.0691, -0.0908, -0.0957,  0.1037,  0.0547,  0.0738,
#           0.0822,  0.0049],
#         [-0.0345,  0.0517, -0.0764, -0.0649, -0.0884,  0.0868,  0.0616,  0.0616,
#           0.0491, -0.0246],
#         [-0.0597,  0.0701, -0.0671, -0.0990, -0.1005,  0.0989,  0.0638,  0.0743,
#           0.0514, -0.0005],
#         [-0.0353,  0.0640, -0.0871, -0.0793, -0.0945,  0.0761,  0.0736,  0.0697,
# ...

# %%
# loss function
loss_fn = nn.CrossEntropyLoss()
# optimizer
optimizer = torch.optim.Adam(model3.parameters(), lr=0.001)

# %%
num_epochs = 50
train_loss_convolution = []
val_loss_convolution = []

for epoch in range(num_epochs):
  model3.train()
  running_loss = 0.0
  for images, classes in train_loader:
    images, classes = images.to(device), classes.to(device)
    optimizer.zero_grad()
    outputs = model3(images)
    l1_norm = sum(p.abs().sum() for p in model3.parameters())
    loss = loss_fn(outputs, classes) + 0.001 * l1_norm
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
  train_loss_convolution.append(running_loss / len(train_loader.dataset))

  model3.eval()
  running_loss = 0.0
  with torch.no_grad():
    for images, classes in val_loader:
      images, classes = images.to(device), classes.to(device)
      outputs = model3(images)
      loss = loss_fn(outputs, classes)
      running_loss += loss.item()
  val_loss_convolution.append(running_loss / len(val_loader.dataset))

  print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss_convolution[-1]:.4f}, Val Loss: {val_loss_convolution[-1]:.4f}")
# Out:
# Epoch 1/50, Train Loss: 0.0111, Val Loss: 0.0026
# Epoch 2/50, Train Loss: 0.0070, Val Loss: 0.0025
# Epoch 3/50, Train Loss: 0.0065, Val Loss: 0.0020
# Epoch 4/50, Train Loss: 0.0062, Val Loss: 0.0018
# Epoch 5/50, Train Loss: 0.0060, Val Loss: 0.0019
# Epoch 6/50, Train Loss: 0.0058, Val Loss: 0.0018
# Epoch 7/50, Train Loss: 0.0057, Val Loss: 0.0019
# Epoch 8/50, Train Loss: 0.0056, Val Loss: 0.0017
# Epoch 9/50, Train Loss: 0.0055, Val Loss: 0.0017
# Epoch 10/50, Train Loss: 0.0055, Val Loss: 0.0016
# Epoch 11/50, Train Loss: 0.0054, Val Loss: 0.0017
# Epoch 12/50, Train Loss: 0.0053, Val Loss: 0.0016
# Epoch 13/50, Train Loss: 0.0053, Val Loss: 0.0016
# Epoch 14/50, Train Loss: 0.0053, Val Loss: 0.0016
# Epoch 15/50, Train Loss: 0.0053, Val Loss: 0.0016
# Epoch 16/50, Train Loss: 0.0052, Val Loss: 0.0015
# Epoch 17/50, Train Loss: 0.0052, Val Loss: 0.0016
# Epoch 18/50, Train Loss: 0.0052, Val Loss: 0.0016
# Epoch 19/50, Train Loss: 0.0052, Val Loss: 0.0016
# ...

# %%
plt.plot(train_loss_convolution, label='Train Loss')
plt.plot(val_loss_convolution, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

outputs = model3(torch.from_numpy(X_test).to(device))
_, predicted = torch.max(outputs, 1)
print(classification_report(y_test, predicted.cpu().numpy()))

print(accuracy_score(y_test, predicted.cpu().numpy()))

plt.imshow(confusion_matrix(y_test, predicted.cpu().numpy()), cmap='Blues')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.80      1000
#            1       0.99      0.96      0.98      1000
#            2       0.78      0.81      0.79      1000
#            3       0.81      0.92      0.86      1000
#            4       0.77      0.81      0.79      1000
#            5       0.97      0.93      0.95      1000
#            6       0.67      0.62      0.64      1000
#            7       0.92      0.94      0.93      1000
#            8       0.95      0.96      0.95      1000
#            9       0.93      0.95      0.94      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000
#
# 0.8647

# %% [markdown]
# How do they compare?

# %%
plt.plot(train_loss_convolution, label='Train Loss')
plt.plot(val_loss_convolution, label='Validation Loss')
plt.plot(train_loss_pretrained, label='Train Loss Pretrained')
plt.plot(val_loss_pretrained, label='Validation Loss Pretrained')
plt.plot(train_loss, label='Train Loss MLP')
plt.plot(val_loss, label='Validation Loss MLP')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
